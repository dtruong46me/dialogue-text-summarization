# %%
# !rm -r "/kaggle/working/dialogue-text-summarization"

# %%
# !git clone -b dev/eval_metric "https://github.com/dtruong46me/dialogue-text-summarization.git"
# Out:
# Cloning into 'dialogue-text-summarization'...
# remote: Enumerating objects: 925, done.
# remote: Counting objects: 100% (120/120), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 925 (delta 25), reused 38 (delta 16), pack-reused 805
# Receiving objects: 100% (925/925), 3.83 MiB | 32.42 MiB/s, done.
# Resolving deltas: 100% (531/531), done.

# %% [markdown]
# ## Setup

# %%
# !bash "/kaggle/working/dialogue-text-summarization/setup.sh"
# Out:
# Xin chao anh em!
# Chung toi dang setup moi truong ...
# ...
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: '/content/dialogue-text-summarization/requirements.txt'
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# ---------
# Set up complete!

# %% [markdown]
# ## Training
#
# > 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
#
# > c74fcec22fbb4be075a981b1f3db3f464b15b089

# %%
# !python "/kaggle/working/dialogue-text-summarization/run_training.py"\
--huggingface_hub_token "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"\
--wandb_token "c74fcec22fbb4be075a981b1f3db3f464b15b089"\
--checkpoint "facebook/bart-large"\
--datapath "knkarthick/dialogsum"\
--output_dir "bart-large-lora"\
--overwrite_output_dir \
--num_train_epochs 30\
--per_device_train_batch_size 4\
--per_device_eval_batch_size 4\
--gradient_accumulation_steps 2\
--learning_rate 0.00005\
--evaluation_strategy "epoch"\
--save_strategy "epoch"\
--logging_strategy "epoch"\
--predict_with_generate \
--save_total_limit 1\
--report_to "wandb"\
--run_name "train_bart"\
--lora \
--target_modules "q_proj,k_proj,v_proj"\
--lora_rank 128\
--lora_alpha 16\
--min_new_tokens 10\
--max_new_tokens 256\
--temperature 0.8\
--top_p 1.0\
--top_k 50
# Out:
# 2024-05-30 09:37:04.686470: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-30 09:37:04.686533: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-30 09:37:04.688180: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loaded argument parsers
# Token has not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# Successful login to Huggingface Hub
# ...

# %% [markdown]
# ## Evaluation

# %%
# !python "/kaggle/working/dialogue-text-summarization/run_evaluation.py"\
--datapath "knkarthick/dialogsum"\
--checkpoint "dtruong46me/bart-large-lora"\
--resultpath "/kaggle/working/dialogue-text-summarization/results/rouge_score.csv"\
--min_new_tokens 10\
--max_new_tokens 256\
--temperature 0.9\
--top_p 1.0\
--top_k 50
# Out:
# 2024-05-31 04:25:16.018661: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-31 04:25:16.018736: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-31 04:25:16.020242: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
#  + datapath=knkarthick/dialogsum
#  + checkpoint=dtruong46me/train-bart-base
#  + resultpath=/kaggle/working/dialogue-text-summarization/results/rouge_score.csv
#  + min_new_tokens=10
#  + max_new_tokens=256
#  + temperature=0.9
#  + top_p=1.0
#  + top_k=50
# ...
# Load Bart model from checkpoint: dtruong46me/train-bart-base
# ...
